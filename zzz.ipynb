# %%
# Python3 program explaining work

# of randint() function



# imports random module

import random


# Generates a random number between

# a given positive range

r1 = random.randint(0, 10)

print("Random number between 0 and 10 is % s" % (r1))


# Generates a random number between

# two given negative range

r2 = random.randint(-10, -1)

print("Random number between -10 and -1 is % d" % (r2))



# Generates a random number between

# a positive and a negative range

r3 = random.randint(-5, 5)

print("Random number between -5 and 5 is % d" % (r3))
# Out:
# Random number between 0 and 10 is 7
# Random number between -10 and -1 is -5
# Random number between -5 and 5 is  5

# %%
# imports random module
import random
'''If we pass floating point values as  parameters in the randint() function'''

r1 = random.randint(1.23, 9.34)
print(r1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7756/1479802366.py in <module>
#       3 '''If we pass floating point values as  parameters in the randint() function'''
#       4
# ----> 5 r1 = random.randint(1.23, 9.34)
#       6 print(r1)
#
# ~\anaconda3\lib\random.py in randint(self, a, b)
#     336         """
#     337
# --> 338         return self.randrange(a, b+1)
#     339
#     340
#
# ~\anaconda3\lib\random.py in randrange(self, start, stop, step)
#     300         istart = int(start)
#     301         if istart != start:
# --> 302             raise ValueError("non-integer arg 1 for randrange()")
#     303         if stop is None:
#     304             if istart > 0:
#
# ValueError: non-integer arg 1 for randrange()

# %%
# imports random
import random

'''If we pass string or character literals as parameters in the randint() function'''

r2 = random.randint('a', 'z')
print(r2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7756/3720842752.py in <module>
#       4 '''If we pass string or character literals as parameters in the randint() function'''
#       5
# ----> 6 r2 = random.randint('a', 'z')
#       7 print(r2)
#
# ~\anaconda3\lib\random.py in randint(self, a, b)
#     336         """
#     337
# --> 338         return self.randrange(a, b+1)
#     339
#     340
#
# TypeError: can only concatenate str (not "int") to str
