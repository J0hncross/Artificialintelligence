# %%
x=5
y=10
print(x + y)
# Out:
# 15

# %%
x=range(6)
print(x)
# Out:
# range(0, 6)

# %%
x={"name":"John","Age":36}
print(x)
# Out:
# {'name': 'John', 'Age': 36}

# %%
x=frozenset({"Apple","Banana","Chery"})
print(x)
# Out:
# frozenset({'Apple', 'Banana', 'Chery'})

# %%
x = True
print(x)
# Out:
# True

# %%
x=b"Hello"
print(x)
# Out:
# b'Hello'

# %%
x=bytearray(5)
print(x)
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')

# %%
x=memoryview(bytes(5))
print(x)
# Out:
# <memory at 0x000001A8E714F280>

# %%
x=int(1)
y=int(2.8)
z=int("3")
print('x = ',x)
print('y = ',y)
print('z = ',z)
# Out:
# x =  1
# y =  2
# z =  3

# %%
x=float(1)
y=float(2.8)
z=float("3")
w=float("4.2")
print('x = ',x)
print('y = ',y)
print('z = ',z)
print('w = ',w)
# Out:
# x =  1.0
# y =  2.8
# z =  3.0
# w =  4.2

# %%
b="Selamat Makan"
print(b[2:5])
# Out:
# lam

# %%
print(b[:5])
# Out:
# Selam

# %%
fruits=["Apple","Banana","Chery"]
tropical=["Mango","Pineapple","Papaya"]
fruits.extend(tropical)
print(fruits)
# Out:
# ['Apple', 'Banana', 'Chery', 'Mango', 'Pineapple', 'Papaya']

# %%
fruits.remove("Banana")
print(fruits)
# Out:
# ['Apple', 'Chery', 'Mango', 'Pineapple', 'Papaya']

# %%
a=23
b=200
if b>a:
    print("b is greater then a")
# Out:
# b is greater then a

# %%
a=200
b=33
if b>a:
print("b is grater then a")
else:
    print("b is not greater then a")
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_15076/303591387.py", line 4
#     print("b is grater then a")
#     ^
# IndentationError: expected an indented block

# %%
a=33
b=33
if b>a:
    print("b is grater then a")
elif a==b:
    print("b is not greater then a")
# Out:
# b is not greater then a

# %%
a=200
b=33
c=500
if b > a and c > a:
    print("Both conditions are True")

# %%
if b > a or c > a:
    print("At least one of the conditions si True")
# Out:
# At least one of the conditions si True

# %%
x=41
if x>10:
print("Above ten,")
if x>20:
    print("and also above 20!")
else:
    print("but not above 20.")
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_15076/2631621800.py", line 3
#     print("Above ten,")
#     ^
# IndentationError: expected an indented block

# %%
i=1
while i<6:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i<6:
    print(i)
    if i==3:
    break
    i+=1
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_15076/2458414390.py", line 5
#     break
#     ^
# IndentationError: expected an indented block

# %%
i=0
while i<6:
    print(i)
    i+=1
    if i==3:
    continue
    print(i)
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_15076/2312239814.py", line 6
#     continue
#     ^
# IndentationError: expected an indented block

# %%
for x in fruits:
    print(x)
# Out:
# Apple
# Chery
# Mango
# Pineapple
# Papaya

# %%
for x in "Banana":
    print(x)
# Out:
# B
# a
# n
# a
# n
# a

# %%
fruits=["Apple","Banana","Cherry"]
for x in fruits:
    print(x)
    if x=="Banana":
        continue
        print(x)
# Out:
# Apple
# Banana
# Cherry

# %%
fruits=["Apple","Banana","Cherry"]
for x in fruits:
    print(x)
    if x=="Banana":
        break
        print(x)
# Out:
# Apple
# Banana

# %%
for x in range(6):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2,6):
    print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
for x in range(2,30,3):
    print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
adj=["red","big","testy"]
fruits=["Apple","Banana","Cherry"]

for x in adj:
    for y in fruits:
        print(x,y)
# Out:
# red Apple
# red Banana
# red Cherry
# big Apple
# big Banana
# big Cherry
# testy Apple
# testy Banana
# testy Cherry

# %%
#mendefinisikan fungsi
def my_function():
print("Hello from a function")
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_15076/1128942043.py", line 3
#     print("Hello from a function")
#     ^
# IndentationError: expected an indented block

# %%
#memanggil fungsi
my_function()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15076/3810326577.py in <module>
#       1 #memanggil fungsi
# ----> 2 my_function()
#
# NameError: name 'my_function' is not defined

# %%
def my_function(fname):
print(fname+"Refsnes")

my_function("emil")
my_function("Tobas")
my_function("Linus")
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_15076/1562544507.py", line 2
#     print(fname+"Refsnes")
#     ^
# IndentationError: expected an indented block

# %%
def my_function(x):
    return 5*x

print(my_function(3))
print(my_function(5))
print(my_function(9))
# Out:
# 15
# 25
# 45
