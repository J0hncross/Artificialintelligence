# %%
print('Hello world')
# Out:
# Hello world

# %%
x=5
y=6.7
print('Nilai Variabel x=',x)
print('Nilai Variabel y=',y)
# Out:
# Nilai Variabel x= 5
# Nilai Variabel y= 6.7

# %%
z1=x+y
z2=x-y
z3=x*y
z4=x/y

print('Niali Variabel z1 =',z1)
print('Niali Variabel z2 =',z2)
print('Niali Variabel z3 =',z3)
print('Niali Variabel z4 =',z4)
# Out:
# Niali Variabel z1 = 11.7
# Niali Variabel z2 = -1.7000000000000002
# Niali Variabel z3 = 33.5
# Niali Variabel z4 = 0.7462686567164178

# %%
a=5
b=2
c1=a**b
c2=a%b

print('Nilai Variabel c1 =',c1)
print('Nilai Variabel c2 =',c2)
# Out:
# Nilai Variabel c1 = 25
# Nilai Variabel c2 = 1

# %%
str='Belajar Pemrograman Python'
print(str)
# Out:
# Belajar Pemrograman Python

# %%
import sys
print(sys.version)
# Out:
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]

# %%
if 5 > 2:
    print('Lima lebih besar dari dua')
# Out:
# Lima lebih besar dari dua

# %%
#comment
print('Hello world')
print('Hello world')#comment
# Out:
# Hello world
# Hello world

# %%
x=5
y='john'
z=3.14
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x1="john"
x2='john'
print(x1)
print(x2)
# Out:
# john
# john

# %%
a=4
A='empat'
print(a)
print(A)
# Out:
# 4
# empat

# %%
myvar='john'
my_var='john'
_my_var='john'
myVar='john'
MYVAR='john'
myvar='john2'

# %%
x,y,z="orange","banana","cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %%
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
fruits=["orange","banana","cherry"]
print(fruits)
# Out:
# ['orange', 'banana', 'cherry']

# %%
number=[1,2,3,4,5]
print(number)
# Out:
# [1, 2, 3, 4, 5]

# %%
mixed=[1,"orange",2,"banana",3,"cherry"]
print(mixed)
# Out:
# [1, 'orange', 2, 'banana', 3, 'cherry']

# %%
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %%
fruits=["orange","banana","cherry"]
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[-1])
print(fruits[-2])
# Out:
# orange
# banana
# cherry
# cherry
# banana

# %%
fruits["orange","banana","cherry","kiwi","melon","mango"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_980/1953436129.py in <module>
# ----> 1 fruits["orange","banana","cherry","kiwi","melon","mango"]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
print(fruits[2:5])
# Out:
# ['cherry']

# %%
fruits.insert(1,"orange")
print(fruits)
# Out:
# ['orange', 'orange', 'banana', 'cherry']

# %%
fruits["orange","banana","cherry","kiwi","melon","mango"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_980/1953436129.py in <module>
# ----> 1 fruits["orange","banana","cherry","kiwi","melon","mango"]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
fruits[1:3]=["Blacberry","watermelon"]

# %%
print(fruits)
# Out:
# ['orange', 'Blacberry', 'watermelon', 'cherry']

# %%
x= "awesome"
print("pythone is"+x)

# %%
x= "awesome"
print("pythone is",x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_980/803178170.py in <module>
#       1 x= "awesome"
# ----> 2 print("pythone is",x)
#
# TypeError: 'str' object is not callable

# %%
x=5
y=10
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_980/4142013691.py in <module>
#       1 x=5
#       2 y=10
# ----> 3 print(x + y)
#
# TypeError: 'str' object is not callable

# %%
print("Hai")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_980/2607544584.py in <module>
# ----> 1 print("Hai")
#
# TypeError: 'str' object is not callable
